# %% [markdown]
# #### Constructing and plotting graphs with Python’s NetworkX through the following template.

# %%
import networkx as nx
from networkx.algorithms import bipartite
import matplotlib.pyplot as plt
from collections import Counter
import random
import math
import numpy as np
import pygraphviz
from networkx.drawing.nx_agraph import graphviz_layout
from networkx.drawing.nx_agraph import to_agraph

# %% [markdown]
# ### 1. Undirected Simple Graphs

# %% [markdown]
# #### 1.1 Erdos-Renyi Random Undirected Graph

# %%
nodes=random.randint(47,52)
p=random.uniform(0.05,0.08)
name="Erdos-Renyi random graph"
G=nx.erdos_renyi_graph(nodes,p)
G=nx.Graph(G,name=name)
print "Graph G is a %s with %i nodes, p=%.3f and %i edges\n" %(str(G),len(G.nodes()),p,len(G.edges()))
# Out:
# Graph G is a Erdos-Renyi random graph with 48 nodes, p=0.050 and 48 edges

# %%
if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
# Out:
# G is a simple graph
# G is an unweighted graph
# G is an undirected graph
# G is not a bipartite graph
# G is not a tree
# G is a disconnected graph and it has 7 connected components
# G has 5 isolates

# %%
pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.4)
nx.draw_networkx_edges(G, pos,arrowsize=20, edge_color="b", alpha=0.7)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# #### 1.2 Gnm Random Undirected Graph

# %%
nodes=random.randint(47,52)
edges=random.randint(70,80)
name="Gnm random graph"
G=nx.gnm_random_graph(nodes,edges)
G=nx.Graph(G,name=name)
print "Graph G is a %s with %i nodes and %i edges\n" %(str(G),len(G.nodes()),len(G.edges()))
# Out:
# Graph G is a Gnm random graph with 47 nodes and 76 edges

# %%
# Copy, paste and run cell 3 here:

if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
# Out:
# G is a simple graph
# G is an unweighted graph
# G is an undirected graph
# G is not a bipartite graph
# G is not a tree
# G is a disconnected graph and it has 2 connected components
# G has 1 isolates

# %%
# Copy, paste and run cell 4 here:

pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.4)
nx.draw_networkx_edges(G, pos,arrowsize=20, edge_color="b", alpha=0.7)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# #### 1.3 Strogatz-Watts Small-World Graph

# %%
nodes=random.randint(47,52)
k=random.randint(5,8) #Each node is joined with its k nearest neighbors in a ring topology
p=random.uniform(0.7,0.8) #rewiring probability
name="Strogatz-Watts graph"
G=nx.watts_strogatz_graph(nodes, k, p)
G=nx.Graph(G,name=name)
print "Graph G is a %s with %i nodes, k=%i, p=%.2f and %i edges\n" %(str(G),len(G.nodes()),k,p,len(G.edges()))
# Out:
# Graph G is a Strogatz-Watts graph with 49 nodes, k=6, p=0.75 and 147 edges

# %%
# Copy, paste and run cell 3 here:

if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
# Out:
# G is a simple graph
# G is an unweighted graph
# G is an undirected graph
# G is not a bipartite graph
# G is not a tree
# G is a connected graph
# G has no isolates

# %%
# Copy, paste and run cell 4 here:

pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.4)
nx.draw_networkx_edges(G, pos,arrowsize=20, edge_color="b", alpha=0.7)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# #### 1.4 Barabasi-Albert Preferential Attachment Graph

# %%
n=random.randint(47,52) #no of nodes
m=random.randint(3,6) #Number of edges to attach from a new node to existing nodes
name="Barabasi-Albert graph"
G=nx.barabasi_albert_graph(n, m)
G=nx.Graph(G,name=name)
print "Graph G is a %s with %i nodes, m=%i and %i edges\n" %(str(G),len(G.nodes()),m,len(G.edges()))
# Out:
# Graph G is a Barabasi-Albert graph with 51 nodes, m=5 and 230 edges

# %%
# Copy, paste and run cell 3 here:

if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
# Out:
# G is a simple graph
# G is an unweighted graph
# G is an undirected graph
# G is not a bipartite graph
# G is not a tree
# G is a connected graph
# G has no isolates

# %%
# Copy, paste and run cell 4 here:

pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.4)
nx.draw_networkx_edges(G, pos,arrowsize=20, edge_color="b", alpha=0.7)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# #### 1.5 Random Regular Graph

# %%
while True:
    n=random.randint(47,52) #no of nodes
    d=random.randint(5,8) #the common degree of nodes
    if n*d%2==0:
        break
name="Random regular graph"
G=nx.random_regular_graph(d, n)
G=nx.Graph(G,name=name)
print "Graph G is a %s with %i nodes, d=%i and %i edges\n" %(str(G),len(G.nodes()),d,len(G.edges()))
# Out:
# Graph G is a Random regular graph with 50 nodes, d=6 and 150 edges

# %%
# Copy, paste and run cell 3 here:

if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
# Out:
# G is a simple graph
# G is an unweighted graph
# G is an undirected graph
# G is not a bipartite graph
# G is not a tree
# G is a connected graph
# G has no isolates

# %%
# Copy, paste and run cell 4 here:

pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.4)
nx.draw_networkx_edges(G, pos,arrowsize=20, edge_color="b", alpha=0.7)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# ### 2. Directed Simple Graphs

# %% [markdown]
# #### 2.1 Erdos-Renyi Random Directed Graph

# %%
nodes=random.randint(37,42)
p=random.uniform(0.05,0.08)
name="Erdos-Renyi random graph"
G=nx.erdos_renyi_graph(nodes,p,directed=True)
G=nx.DiGraph(G,name=name)
print "Directed graph G is a %s with %i nodes, p=%.3f and %i edges\n" %(str(G),len(G.nodes()),p,len(G.edges()))
# Out:
# Directed graph G is a Erdos-Renyi random graph with 42 nodes, p=0.066 and 111 edges

# %%
# Copy, paste and run cell 3 here:

if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
# Out:
# G is a simple graph
# G is an unweighted graph
# G is a directed graph
# G is not a bipartite graph
# G is not a tree
# G is not strongly connected and it has 6 strongly connected components
# G is a weakly connected graph
# G has no isolates

# %%
# Copy, paste and run cell 4 here:

pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.4)
nx.draw_networkx_edges(G, pos,arrowsize=20, edge_color="b", alpha=0.7)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# #### 2.2 Gnm Random Directed Graph

# %%
nodes=random.randint(37,42)
edges=random.randint(70,80)
name="Gnm random graph"
G=nx.gnm_random_graph(nodes,edges)
G=nx.DiGraph(G,name=name)
print "Directed graph G is a %s with %i nodes and %i edges" %(str(G),len(G.nodes()),len(G.edges()))
# Out:
# Directed graph G is a Gnm random graph with 40 nodes and 158 edges

# %%
# Copy, paste and run cell 3 here:

if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
# Out:
# G is a simple graph
# G is an unweighted graph
# G is a directed graph
# G is not a bipartite graph
# G is not a tree
# G is a strongly connected graph
# G is a weakly connected graph
# G has no isolates

# %%
# Copy, paste and run cell 4 here:

pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.4)
nx.draw_networkx_edges(G, pos,arrowsize=20, edge_color="b", alpha=0.7)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# ### 3. Bipartite Graphs

# %%
n = random.randint(10,15)   #nodes of the first partition
m = random.randint(10,15)   #nodes of the second partition
p=random.uniform(0.1,0.2)   #probability of edge existence
name="Bipartite random graph"
alls=[]
for y in range(n,n+m):
    for x in range(n):
        alls.append((x,y))
eds=random.sample(alls,int(p*len(alls)))
G=nx.Graph()
G.add_edges_from(eds)
G=nx.Graph(G,name=name)
X=[z for z in G.nodes() if z in range(n)]
Y=[z for z in G.nodes() if z in range(n,n+m)]
print "Graph G is a %s with %i nodes (%i nodes in the first partition, %i nodes in the second partition), p=%.2f and %i edges\n" %(str(G),len(G.nodes()),len(X),len(Y),p,len(G.edges()))
# Out:
# Graph G is a Bipartite random graph with 25 nodes (13 nodes in the first partition, 12 nodes in the second partition), p=0.17 and 31 edges

# %%
# Copy, paste and run cell 3 here:

if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
# Out:
# G is a simple graph
# G is an unweighted graph
# G is an undirected graph
# G is a bipartite graph
# G is not a tree
# G is a connected graph
# G has no isolates

# %%
pos={}
for i,x in list(enumerate(X)):
    pos[x]=(0,i)
for j,y in list(enumerate(Y)):
    pos[y]=(1,j)
plt.figure(figsize=(8,8));
nodes1 = nx.draw_networkx_nodes(G, pos, nodelist=list(X), node_shape='o', node_color="g", alpha=0.4)
nodes2 = nx.draw_networkx_nodes(G, pos, nodelist=list(Y), node_shape='s', node_color="cyan", alpha=0.4)
nx.draw_networkx_edges(G, pos,arrowsize=20, edge_color="b", alpha=0.6)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# ### 4. Trees

# %% [markdown]
# #### 4.1 Balanced Tree

# %%
r=random.randint(2,3) #number of children of each node
h=random.randint(2,4) #number of generations (height)
name="Balanced tree"
G=nx.balanced_tree(r, h)
G=nx.Graph(G,name=name)
print "Tree G is a %s with %i nodes, r=%i, h=%i and %i edges" %(str(G),len(G.nodes()),r,h,len(G.edges()))
# Out:
# Tree G is a Balanced tree with 40 nodes, r=3, h=3 and 39 edges

# %%
# Copy, paste and run cell 3 here:

if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
# Out:
# G is a simple graph
# G is an unweighted graph
# G is an undirected graph
# G is a bipartite graph
# G is a tree
# G is a connected graph
# G has no isolates

# %%
plt.figure(figsize=(8,8));
pos=graphviz_layout(G, prog='dot') #, args="-Grankdir=LR")
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.4)#,)
nx.draw_networkx_edges(G, pos, edge_color='b', alpha=0.7)
nx.draw_networkx_labels(G, pos,font_size=8)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# #### 4.2 Random Power Law Tree

# %%
n=random.randint(25,35) #number of nodes
name="Random power law tree"
G=nx.random_powerlaw_tree(n,tries=1000)
G=nx.Graph(G,name=name)
print "Tree G is a %s with %i nodes and %i edges" %(str(G),len(G.nodes()),len(G.edges()))
# Out:
# Tree G is a Random power law tree with 26 nodes and 25 edges

# %%
# Copy, paste and run cell 3 here:

if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
# Out:
# G is a simple graph
# G is an unweighted graph
# G is an undirected graph
# G is a bipartite graph
# G is a tree
# G is a connected graph
# G has no isolates

# %%
# Copy, paste and run cell 28 here:

plt.figure(figsize=(8,8));
pos=graphviz_layout(G, prog='dot') #, args="-Grankdir=LR")
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.4)#,)
nx.draw_networkx_edges(G, pos, edge_color='b', alpha=0.7)
nx.draw_networkx_labels(G, pos,font_size=8)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# ### 5. Weighted Graphs

# %% [markdown]
# #### Function alocating randomly integer weights on edges of a graph

# %%
def weight_attr(G,maxw):
    # G is a graph
    # maxw is a positive integer (maximum weight value)
    weight={}
    for edge in G.edges():
        ed=edge[0]
        de=edge[1]
        G[ed][de]['weight']=random.randrange(1,maxw)
        weight[(ed,de)]=G[ed][de]['weight']
    return weight

# %% [markdown]
# #### 5.1 Erdos-Renyi Random Weighted Graph

# %%
nodes=random.randint(47,52)
p=random.uniform(0.05,0.08)
name="Erdos-Renyi random weighted graph"
G=nx.erdos_renyi_graph(nodes,p)
maxw=random.randint(7,12)
weight=weight_attr(G,maxw)
w_edges=[(x,y,z) for (x,y),z in weight.items()]
G.add_weighted_edges_from(w_edges)
G=nx.Graph(G,name=name)
print "Graph G is a %s with %i nodes, p=%.3f and %i edges\n" %(str(G),len(G.nodes()),p,len(G.edges()))

res = list(sorted(Counter(G.edges()), key=Counter(G.edges()).__getitem__, reverse=True))
for i in res:
    print "Edge", i, "has weight", Counter(G.edges())[i]['weight']
# Out:
# Graph G is a Erdos-Renyi random weighted graph with 50 nodes, p=0.066 and 86 edges
#
# Edge (25, 43) has weight 8
# Edge (28, 48) has weight 8
# Edge (3, 40) has weight 8
# Edge (2, 32) has weight 8
# Edge (10, 41) has weight 8
# Edge (27, 49) has weight 8
# Edge (20, 44) has weight 8
# Edge (16, 49) has weight 8
# Edge (22, 40) has weight 8
# Edge (18, 29) has weight 8
# Edge (4, 30) has weight 8
# Edge (15, 20) has weight 7
# Edge (37, 48) has weight 7
# Edge (0, 30) has weight 7
# Edge (4, 28) has weight 7
# Edge (0, 18) has weight 7
# Edge (35, 39) has weight 7
# Edge (19, 45) has weight 7
# Edge (9, 46) has weight 7
# Edge (25, 49) has weight 6
# Edge (1, 31) has weight 6
# Edge (0, 14) has weight 6
# Edge (15, 19) has weight 6
# Edge (3, 47) has weight 6
# Edge (25, 36) has weight 6
# Edge (17, 41) has weight 6
# Edge (14, 48) has weight 6
# Edge (12, 22) has weight 5
# Edge (2, 28) has weight 5
# Edge (18, 25) has weight 5
# Edge (25, 33) has weight 5
# Edge (9, 40) has weight 5
# Edge (24, 34) has weight 5
# Edge (25, 28) has weight 5
# Edge (1, 17) has weight 4
# Edge (14, 15) has weight 4
# Edge (33, 34) has weight 4
# Edge (2, 18) has weight 4
# Edge (25, 42) has weight 4
# Edge (21, 33) has weight 4
# Edge (10, 19) has weight 4
# Edge (34, 38) has weight 4
# Edge (25, 29) has weight 4
# Edge (2, 45) has weight 4
# Edge (12, 38) has weight 4
# Edge (3, 29) has weight 4
# Edge (34, 46) has weight 3
# Edge (35, 36) has weight 3
# Edge (0, 39) has weight 3
# Edge (13, 38) has weight 3
# Edge (11, 31) has weight 3
# Edge (35, 44) has weight 3
# Edge (38, 45) has weight 3
# Edge (41, 49) has weight 3
# Edge (40, 49) has weight 3
# Edge (3, 26) has weight 3
# Edge (0, 34) has weight 3
# Edge (7, 13) has weight 3
# Edge (12, 43) has weight 3
# Edge (21, 37) has weight 2
# Edge (6, 13) has weight 2
# Edge (9, 25) has weight 2
# Edge (4, 42) has weight 2
# Edge (40, 48) has weight 2
# Edge (6, 48) has weight 2
# Edge (14, 38) has weight 2
# Edge (25, 35) has weight 2
# Edge (38, 48) has weight 2
# Edge (35, 49) has weight 2
# Edge (0, 9) has weight 2
# Edge (10, 40) has weight 2
# Edge (25, 31) has weight 1
# Edge (31, 44) has weight 1
# Edge (12, 34) has weight 1
# Edge (6, 41) has weight 1
# Edge (5, 27) has weight 1
# Edge (8, 32) has weight 1
# Edge (11, 26) has weight 1
# Edge (22, 29) has weight 1
# Edge (4, 33) has weight 1
# Edge (17, 28) has weight 1
# Edge (31, 36) has weight 1
# Edge (4, 23) has weight 1
# Edge (34, 40) has weight 1
# Edge (19, 20) has weight 1
# Edge (30, 44) has weight 1

# %%
# Copy, paste and run cell 3 here:

if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
# Out:
# G is a simple graph
# G is a weighted graph
# G is an undirected graph
# G is not a bipartite graph
# G is not a tree
# G is a connected graph
# G has no isolates

# %%
edge_width=[G[u][v]['weight'] for u,v in G.edges()] 
edge_width=[w for w in edge_width]

pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.3)
nx.draw_networkx_edges(G, pos,arrowsize=20, width=edge_width, edge_color="b", alpha=0.5)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# #### 5.2 Gnm Random Weighted  Graph

# %%
nodes=random.randint(47,52)
edges=random.randint(70,80)
name="Gnm random weighted graph"
G=nx.gnm_random_graph(nodes,edges)
maxw=random.randint(7,12)
weight=weight_attr(G,maxw)
w_edges=[(x,y,z) for (x,y),z in weight.items()]
G.add_weighted_edges_from(w_edges)
G=nx.Graph(G,name=name)
print "Graph G is a %s with %i nodes and %i edges\n" %(str(G),len(G.nodes()),len(G.edges()))

res = list(sorted(Counter(G.edges()), key=Counter(G.edges()).__getitem__, reverse=True))
for i in res:
    print "Edge", i, "has weight", Counter(G.edges())[i]['weight']
# Out:
# Graph G is a Gnm random weighted graph with 47 nodes and 70 edges
#
# Edge (5, 6) has weight 7
# Edge (20, 43) has weight 7
# Edge (11, 38) has weight 7
# Edge (11, 12) has weight 7
# Edge (7, 23) has weight 7
# Edge (19, 31) has weight 7
# Edge (16, 19) has weight 7
# Edge (17, 34) has weight 7
# Edge (16, 31) has weight 7
# Edge (0, 19) has weight 7
# Edge (2, 33) has weight 7
# Edge (3, 46) has weight 7
# Edge (22, 40) has weight 7
# Edge (39, 46) has weight 6
# Edge (0, 16) has weight 6
# Edge (35, 39) has weight 6
# Edge (7, 29) has weight 6
# Edge (2, 26) has weight 6
# Edge (5, 14) has weight 6
# Edge (10, 13) has weight 6
# Edge (35, 43) has weight 6
# Edge (9, 45) has weight 5
# Edge (16, 29) has weight 5
# Edge (12, 19) has weight 5
# Edge (38, 44) has weight 5
# Edge (0, 24) has weight 5
# Edge (20, 31) has weight 5
# Edge (3, 9) has weight 5
# Edge (10, 37) has weight 4
# Edge (4, 45) has weight 4
# Edge (17, 42) has weight 4
# Edge (1, 45) has weight 4
# Edge (9, 28) has weight 4
# Edge (25, 35) has weight 4
# Edge (29, 45) has weight 4
# Edge (7, 20) has weight 4
# Edge (12, 45) has weight 4
# Edge (14, 44) has weight 4
# Edge (3, 36) has weight 4
# Edge (5, 40) has weight 4
# Edge (37, 41) has weight 3
# Edge (22, 33) has weight 3
# Edge (5, 30) has weight 3
# Edge (3, 34) has weight 3
# Edge (7, 40) has weight 3
# Edge (5, 22) has weight 3
# Edge (22, 28) has weight 3
# Edge (22, 24) has weight 3
# Edge (2, 20) has weight 3
# Edge (12, 42) has weight 3
# Edge (30, 45) has weight 3
# Edge (3, 12) has weight 3
# Edge (33, 46) has weight 3
# Edge (11, 29) has weight 3
# Edge (0, 6) has weight 3
# Edge (29, 31) has weight 2
# Edge (36, 44) has weight 2
# Edge (27, 28) has weight 2
# Edge (24, 35) has weight 2
# Edge (36, 45) has weight 2
# Edge (37, 44) has weight 2
# Edge (31, 43) has weight 1
# Edge (19, 44) has weight 1
# Edge (4, 24) has weight 1
# Edge (16, 20) has weight 1
# Edge (1, 19) has weight 1
# Edge (33, 36) has weight 1
# Edge (3, 8) has weight 1
# Edge (8, 39) has weight 1
# Edge (7, 17) has weight 1

# %%
# Copy, paste and run cell 3 here:

if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
# Out:
# G is a simple graph
# G is a weighted graph
# G is an undirected graph
# G is not a bipartite graph
# G is not a tree
# G is a disconnected graph and it has 5 connected components
# G has 4 isolates

# %%
# Copy, paste and run cell 35 here:

edge_width=[G[u][v]['weight'] for u,v in G.edges()] 
edge_width=[w for w in edge_width]

pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.3)
nx.draw_networkx_edges(G, pos,arrowsize=20, width=edge_width, edge_color="b", alpha=0.5)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# ### 6. Multigraphs

# %% [markdown]
# #### Function adding randomly multiple edges of a graph

# %%
def add_multiedges(G,k):
    # E is a list of edges
    # k is a positive integer for the edges to be added in parallen to existing ones 
    edges = list(G.edges())
    for _ in range(k):
        e=random.choice(list(E))
        edges.append(e)
    Gm = nx.MultiGraph()
    Gm.add_edges_from(edges)
    return Gm

# %% [markdown]
# #### 6.1 Gnm Random Multigraph

# %%
nodes=random.randint(17,22)
edges=random.randint(35,45)
name="Gnm random multigraph"
G=nx.gnm_random_graph(nodes,edges)
E=G.edges()
k=random.randint(50,60)
G=add_multiedges(G,k)
G=nx.MultiGraph(G,name=name)
print "Graph G is a %s with %i nodes and %i edges\n" %(str(G),len(G.nodes()),len(G.edges()))

res = list(sorted(Counter(G.edges()), key=Counter(G.edges()).__getitem__, reverse=True))
for i in res:
    print "Edge", i, "appears", Counter(G.edges())[i], "times"
# Out:
# Graph G is a Gnm random multigraph with 19 nodes and 89 edges
#
# Edge (3, 7) appears 8 times
# Edge (9, 17) appears 5 times
# Edge (4, 7) appears 4 times
# Edge (2, 10) appears 4 times
# Edge (6, 14) appears 4 times
# Edge (0, 17) appears 4 times
# Edge (11, 14) appears 3 times
# Edge (13, 16) appears 3 times
# Edge (2, 13) appears 3 times
# Edge (2, 8) appears 3 times
# Edge (8, 11) appears 3 times
# Edge (0, 18) appears 3 times
# Edge (8, 17) appears 3 times
# Edge (10, 11) appears 2 times
# Edge (4, 8) appears 2 times
# Edge (0, 14) appears 2 times
# Edge (0, 8) appears 2 times
# Edge (12, 13) appears 2 times
# Edge (8, 16) appears 2 times
# Edge (16, 18) appears 2 times
# Edge (5, 11) appears 2 times
# Edge (0, 12) appears 2 times
# Edge (12, 18) appears 2 times
# Edge (2, 7) appears 2 times
# Edge (11, 17) appears 2 times
# Edge (4, 15) appears 2 times
# Edge (7, 13) appears 2 times
# Edge (5, 14) appears 2 times
# Edge (12, 16) appears 1 times
# Edge (2, 9) appears 1 times
# Edge (1, 16) appears 1 times
# Edge (2, 16) appears 1 times
# Edge (2, 14) appears 1 times
# Edge (9, 13) appears 1 times
# Edge (8, 12) appears 1 times
# Edge (10, 16) appears 1 times
# Edge (5, 12) appears 1 times

# %%
# Copy, paste and run cell 3 here:

if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
# Out:
# G is a multigraph
# G is an unweighted graph
# G is an undirected graph
# G is not a bipartite graph
# G is not a tree
# G is a connected graph
# G has no isolates

# %% [markdown]
# #### Plotting the multigraph as a weighted graph

# %%
weight=[(x, y, {'weight': v}) for (x, y), v in Counter(G.edges()).items()]
G = nx.Graph(weight)
edge_width=[G[u][v]['weight'] for u,v in G.edges()]

pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.3)
nx.draw_networkx_edges(G, pos,arrowsize=20, width=edge_width, edge_color="b", alpha=0.5)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);

# %% [markdown]
# #### 6.2 Erdos-Renyi Random Multigraph

# %%
nodes=random.randint(27,32)
p=random.uniform(0.05,0.07)
name="Erdos-Renyi random multigraph"
G=nx.erdos_renyi_graph(nodes,p)
E=G.edges()
k=random.randint(50,60)
G=add_multiedges(G,k)
G=nx.MultiGraph(G,name=name)
print "Graph G is a %s with %i nodes, p=%.3f and %i edges\n" %(str(G),len(G.nodes()),p,len(G.edges()))

res = list(sorted(Counter(G.edges()), key=Counter(G.edges()).__getitem__, reverse=True))
for i in res:
    print "Edge", i, "appears", Counter(G.edges())[i], "times"
# Out:
# Graph G is a Erdos-Renyi random multigraph with 23 nodes, p=0.056 and 87 edges
#
# Edge (9, 26) appears 5 times
# Edge (14, 27) appears 5 times
# Edge (23, 25) appears 5 times
# Edge (3, 13) appears 5 times
# Edge (23, 27) appears 5 times
# Edge (2, 21) appears 5 times
# Edge (7, 14) appears 4 times
# Edge (12, 16) appears 4 times
# Edge (2, 20) appears 4 times
# Edge (4, 14) appears 4 times
# Edge (14, 20) appears 4 times
# Edge (0, 26) appears 4 times
# Edge (4, 25) appears 4 times
# Edge (20, 22) appears 3 times
# Edge (13, 24) appears 3 times
# Edge (6, 11) appears 3 times
# Edge (2, 3) appears 3 times
# Edge (22, 26) appears 2 times
# Edge (4, 27) appears 2 times
# Edge (20, 26) appears 2 times
# Edge (10, 12) appears 2 times
# Edge (1, 24) appears 2 times
# Edge (4, 20) appears 2 times
# Edge (7, 8) appears 2 times
# Edge (2, 14) appears 1 times
# Edge (3, 23) appears 1 times
# Edge (21, 25) appears 1 times

# %%
# Copy, paste and run cell 3 here:

if G.is_multigraph()==True:
    print "G is a multigraph"
else:
    print "G is a simple graph"
if nx.is_weighted(G)==True:
    print "G is a weighted graph"
else:
    print "G is an unweighted graph"
if G.is_directed()==True:
    print "G is a directed graph"
else:
    print "G is an undirected graph"    
if nx.is_bipartite(G)==True:
    print "G is a bipartite graph"
else:
    print "G is not a bipartite graph"    
if nx.is_tree(G)==True:
    print "G is a tree"
else:
    print "G is not a tree"    
if G.is_directed()==False:
    if nx.is_connected(G)==True:
        print "G is a connected graph"
    else:
        print "G is a disconnected graph and it has",nx.number_connected_components(G),"connected components"    
else:
    if nx.is_strongly_connected(G)==True:
        print "G is a strongly connected graph"
    else:
        print "G is not strongly connected and it has",nx.number_strongly_connected_components(G),"strongly connected components"
    if nx.is_weakly_connected(G)==True:
        print "G is a weakly connected graph"
    else:
        print "G is not weakly connected and it has",nx.number_weakly_connected_components(G),"weakly connected components"    
if len(list(nx.isolates(G)))>0:
    print "G has",len(list(nx.isolates(G))),"isolates"
else:
    print "G has no isolates"
# Out:
# G is a multigraph
# G is an unweighted graph
# G is an undirected graph
# G is not a bipartite graph
# G is not a tree
# G is a disconnected graph and it has 3 connected components
# G has no isolates

# %% [markdown]
# #### Plotting the multigraph as a weighted graph

# %%
weight=[(x, y, {'weight': v}) for (x, y), v in Counter(G.edges()).items()]
G = nx.Graph(weight)
edge_width=[G[u][v]['weight'] for u,v in G.edges()]

pos=graphviz_layout(G)
plt.figure(figsize=(8,8));
nodes = nx.draw_networkx_nodes(G, pos, node_color="g", alpha=0.3)
nx.draw_networkx_edges(G, pos,arrowsize=20, width=edge_width, edge_color="b", alpha=0.5)
nx.draw_networkx_labels(G, pos)
plt.axis('off');
plt.title(name,fontsize=15);
